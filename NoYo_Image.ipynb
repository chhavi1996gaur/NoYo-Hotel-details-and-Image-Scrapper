# %%
import re
import requests
from bs4 import BeautifulSoup
sites = ['https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&from_sf=1&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=92014b9132b0010a&ss=Goa%2C%20India&ssb=empty&top_ufis=1&rows=25',
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&dtdisc=0&from_sf=1&group_adults=2&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=2a266e775acc00bb&ss=Goa%2C%20India&ss_all=0&ssb=empty&sshis=0&top_ufis=1&rows=25&offset=25', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&from_sf=1&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=6cce819faf8c001f&ss=Goa%2C%20India&ssb=empty&top_ufis=1&rows=25&offset=50', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&dtdisc=0&from_sf=1&group_adults=2&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=eaf08306a9420158&ss=Goa%2C%20India&ss_all=0&ssb=empty&sshis=0&top_ufis=1&rows=25&offset=75', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&from_sf=1&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=2c4583114cbf0189&ss=Goa%2C%20India&ssb=empty&top_ufis=1&rows=25&offset=100', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&dtdisc=0&from_sf=1&group_adults=2&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=9fe2831ade5700e6&ss=Goa%2C%20India&ss_all=0&ssb=empty&sshis=0&top_ufis=1&rows=25&offset=125', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&from_sf=1&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=9c888326d1c800f5&ss=Goa%2C%20India&ssb=empty&top_ufis=1&rows=25&offset=150', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&dtdisc=0&from_sf=1&group_adults=2&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=d5298333cfe9005c&ss=Goa%2C%20India&ss_all=0&ssb=empty&sshis=0&top_ufis=1&rows=25&offset=175', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&from_sf=1&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=d8cd8340d38800aa&ss=Goa%2C%20India&ssb=empty&top_ufis=1&rows=25&offset=200', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&dtdisc=0&from_sf=1&group_adults=2&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=b705834e411e00af&ss=Goa%2C%20India&ss_all=0&ssb=empty&sshis=0&top_ufis=1&rows=25&offset=225', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&from_sf=1&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=7d208359e53f0004&ss=Goa%2C%20India&ssb=empty&top_ufis=1&rows=25&offset=250', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&dtdisc=0&from_sf=1&group_adults=2&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=b2308368fd3500db&ss=Goa%2C%20India&ss_all=0&ssb=empty&sshis=0&top_ufis=1&rows=25&offset=275', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&from_sf=1&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=3d768371204600aa&ss=Goa%2C%20India&ssb=empty&top_ufis=1&rows=25&offset=300', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&dtdisc=0&from_sf=1&group_adults=2&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=76a4837e336a005d&ss=Goa%2C%20India&ss_all=0&ssb=empty&sshis=0&top_ufis=1&rows=25&offset=325', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&from_sf=1&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=5ac183877b4d0079&ss=Goa%2C%20India&ssb=empty&top_ufis=1&rows=25&offset=350', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&dtdisc=0&from_sf=1&group_adults=2&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=fc7a839086e7007b&ss=Goa%2C%20India&ss_all=0&ssb=empty&sshis=0&top_ufis=1&rows=25&offset=375', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&from_sf=1&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=54a183997eb80043&ss=Goa%2C%20India&ssb=empty&top_ufis=1&rows=25&offset=400', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&dtdisc=0&from_sf=1&group_adults=2&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=3ab683a2191e00e6&ss=Goa%2C%20India&ss_all=0&ssb=empty&sshis=0&top_ufis=1&rows=25&offset=425', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&from_sf=1&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=349283aa17940022&ss=Goa%2C%20India&ssb=empty&top_ufis=1&rows=25&offset=450', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&dtdisc=0&from_sf=1&group_adults=2&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=33c983b36628010b&ss=Goa%2C%20India&ss_all=0&ssb=empty&sshis=0&top_ufis=1&rows=25&offset=475', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&from_sf=1&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=48cf83bad6ba0137&ss=Goa%2C%20India&ssb=empty&top_ufis=1&rows=25&offset=500', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&dtdisc=0&from_sf=1&group_adults=2&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=2eef83c19f5a008e&ss=Goa%2C%20India&ss_all=0&ssb=empty&sshis=0&top_ufis=1&rows=25&offset=525', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&from_sf=1&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=db6083c98cdb002e&ss=Goa%2C%20India&ssb=empty&top_ufis=1&rows=25&offset=550', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&dtdisc=0&from_sf=1&group_adults=2&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=eeac83d13328000b&ss=Goa%2C%20India&ss_all=0&ssb=empty&sshis=0&top_ufis=1&rows=25&offset=575', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&from_sf=1&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=7d2083d8e8e0008b&ss=Goa%2C%20India&ssb=empty&top_ufis=1&rows=25&offset=600', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&dtdisc=0&from_sf=1&group_adults=2&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=63b183e214180040&ss=Goa%2C%20India&ss_all=0&ssb=empty&sshis=0&top_ufis=1&rows=25&offset=625', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&from_sf=1&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=aac283ead7fe008a&ss=Goa%2C%20India&ssb=empty&top_ufis=1&rows=25&offset=650', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&dtdisc=0&from_sf=1&group_adults=2&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=3ab683f12f020074&ss=Goa%2C%20India&ss_all=0&ssb=empty&sshis=0&top_ufis=1&rows=25&offset=675', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&from_sf=1&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=bc2183f904c2009b&ss=Goa%2C%20India&ssb=empty&top_ufis=1&rows=25&offset=700', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&dtdisc=0&from_sf=1&group_adults=2&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=20ab8410a89d0085&ss=Goa%2C%20India&ss_all=0&ssb=empty&sshis=0&top_ufis=1&rows=25&offset=775', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&from_sf=1&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=c84b841c76500125&ss=Goa%2C%20India&ssb=empty&top_ufis=1&rows=25&offset=800', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&dtdisc=0&from_sf=1&group_adults=2&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=888f842318810027&ss=Goa%2C%20India&ss_all=0&ssb=empty&sshis=0&top_ufis=1&rows=25&offset=825', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&from_sf=1&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=9fe2842b090a0081&ss=Goa%2C%20India&ssb=empty&top_ufis=1&rows=25&offset=850', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&dtdisc=0&from_sf=1&group_adults=2&group_children=0&inac=0&index_postcard=0&label_click=undef&no_rooms=1&postcard=0&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=2bbf8431a6cb00d4&ss=Goa%2C%20India&ss_all=0&ssb=empty&sshis=0&top_ufis=1&rows=25&offset=875', 
        'https://www.booking.com/searchresults.en-gb.html?aid=304142&label=gen173nr-1DCAEoggI46AdIM1gEaGyIAQGYAQm4ARfIAQzYAQPoAQGIAgGoAgO4AuHsqfwFwAIB0gIkYWNhMWNjMDMtNjg3ZS00MjE4LTg0N2EtNjA1ZjU4YjI5NjEx2AIE4AIB&sid=f4078a962c7d43f3e1fcf61ffb7780c5&tmpl=searchresults&checkin_month=11&checkin_monthday=1&checkin_year=2020&checkout_month=11&checkout_monthday=2&checkout_year=2020&class_interval=1&dest_id=4127&dest_type=region&from_sf=1&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=region&room1=A%2CA&sb_price_type=total&search_selected=1&shw_aparth=1&slp_r_match=0&src=index&src_elem=sb&srpvid=e9d6843872350086&ss=Goa%2C%20India&ssb=empty&top_ufis=1&rows=25&offset=900']



for site in sites:
    response = requests.get(site)

    soup = BeautifulSoup(response.text, 'html.parser')
    img_tags = soup.find_all('img')

    urls = [img['src'] for img in img_tags]


    for url in urls:
        filename = re.search(r'/([\w]+[.](jpg|gif|png))', url)
        if not filename:
            print("Regex didn't match with the url: {}".format(url))
            continue
        with open(filename.group(1), 'wb') as f:
            if 'http' not in url:
                # sometimes an image source can be relative 
                # if it is provide the base url which also happens 
                # to be the site variable atm. 
                url = '{}{}'.format(site, url)
            response = requests.get(url)
            f.write(response.content)
